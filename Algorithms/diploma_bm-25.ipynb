# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.image as mpimg
import math
import time
import seaborn as sns
import warnings
import plotly
import plotly.figure_factory as ff
from plotly.graph_objs import Scatter, Layout

plotly.offline.init_notebook_mode(connected=True)
warnings.filterwarnings("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('data.csv', on_bad_lines='skip')
df
# Out:
#           id  gender masterCategory  subCategory    articleType  baseColour  \
# 0      15970    men        apparel      topwear         shirts   navy blue
# 1      39386    men        apparel   bottomwear          jeans        blue
# 2      59263  women    accessories      watches        watches      silver
# 3      21379    men        apparel   bottomwear    track pants       black
# 4      53759    men        apparel      topwear        tshirts        grey
# ...      ...     ...            ...          ...            ...         ...
# 41686  42234  women        apparel      topwear           tops        blue
# 41687  17036    men       footwear        shoes   casual shoes       white
# 41688   6461    men       footwear   flip flops     flip flops         red
# 41689  18842    men        apparel      topwear        tshirts        blue
# 41690  51623  women    accessories      watches        watches        pink
#
#         season    year    usage  \
# 0        fall   2011.0  casual
# 1      summer   2012.0  casual
# 2      winter   2016.0  casual
# 3        fall   2011.0  casual
# 4      summer   2012.0  casual
# ...        ...     ...      ...
# 41686  summer   2012.0  casual
# 41687  summer   2013.0  casual
# 41688  summer   2011.0  casual
# 41689    fall   2011.0  casual
# 41690  winter   2016.0  casual
#
#                                      productDisplayName      image  \
# 0                     turtle check men navy blue shirt   15970.jpg
# 1                   peter england men party blue jeans   39386.jpg
# 2                             titan women silver watch   59263.jpg
# 3        manchester united men solid black track pants   21379.jpg
# 4                                 puma men grey tshirt   53759.jpg
# ...                                                 ...        ...
# 41686                     sepia women blue printed top   42234.jpg
# 41687                        gas men caddy casual shoe   17036.jpg
# 41688                lotto mens soccer track flip flop    6461.jpg
# 41689             puma men graphic stellar blue tshirt   18842.jpg
# 41690  fossil women pink dial chronograph watch es3050   51623.jpg
#
#                                              allFeatures  \
# 0      shirtmen turtle topwear men fall shirts check ...
# 1      peter party men summer jeansmen blue bottomwea...
# 2      silver watchwomen titan accessories winter wat...
# 3      solid black pantsmen track men fall united bot...
# 4      topwear men tshirts summer puma grey apparel t...
# ...                                                  ...
# 41686  topwomen topwear printed sepia summer tops blu...
# 41687  caddy casual men summer shoemen white shoes ga...
# 41688  flip lotto flopmen track summer mens soccer re...
# 41689  topwear stellar men tshirts puma fall graphic ...
# 41690  chronograph watch dial accessories es3050women...
#
#                                               lemmatised  \
# 0      shirtmen turtle topwear men fall shirt check b...
# 1      peter party men summer jeansmen blue bottomwea...
# 2      silver watchwomen titan accessory winter watch...
# 3      solid black pantsmen track men fall united bot...
# 4      topwear men tshirts summer puma grey apparel t...
# ...                                                  ...
# 41686  topwomen topwear printed sepia summer top blue...
# 41687  caddy casual men summer shoemen white shoe gas...
# 41688  flip lotto flopmen track summer men soccer red...
# 41689  topwear stellar men tshirts puma fall graphic ...
# 41690  chronograph watch dial accessory es3050women w...
#
#                                             snow_stemmed  \
# 0      shirtmen turtl topwear men fall shirt check bl...
# 1      peter parti men summer jeansmen blue bottomwea...
# 2      silver watchwomen titan accessori winter watch...
# 3      solid black pantsmen track men fall unit botto...
# 4      topwear men tshirt summer puma grey apparel ts...
# ...                                                  ...
# 41686  topwomen topwear print sepia summer top blue a...
# 41687  caddi casual men summer shoemen white shoe gas...
# 41688  flip lotto flopmen track summer men soccer red...
# 41689  topwear stellar men tshirt puma fall graphic b...
# 41690  chronograph watch dial accessori es3050women w...
#
#                                                     noun  \
# 0                            shirtmen men shirts apparel
# 1      peter party men summer jeansmen england appare...
# 2            silver watchwomen accessories watches women
# 3                          pantsmen men manchester pants
# 4         men tshirts summer puma grey apparel tshirtmen
# ...                                                  ...
# 41686                         topwomen summer tops women
# 41687                       men summer shoemen shoes gas
# 41688        flip lotto flopmen summer mens soccer flops
# 41689                 men tshirts fall apparel tshirtmen
# 41690  chronograph watch dial accessories winter foss...
#
#                                                stem_lemm  \
# 0      shirtmen turtle topwear men fall shirt check b...
# 1      peter party men summer jeansmen blue bottomwea...
# 2      silver watchwomen titan accessory winter watch...
# 3      solid black pantsmen track men fall united bot...
# 4      topwear men tshirts summer puma grey apparel t...
# ...                                                  ...
# 41686  topwomen topwear printed sepia summer top blue...
# 41687  caddy casual men summer shoemen white shoe gas...
# 41688  flip lotto flopmen track summer men soccer red...
# 41689  topwear stellar men tshirts puma fall graphic ...
# 41690  chronograph watch dial accessory es3050women w...
#
#                                                lemm_stem  \
# 0      shirtmen turtl topwear men fall shirt check bl...
# 1      peter parti men summer jeansmen blue bottomwea...
# 2      silver watchwomen titan accessori winter watch...
# 3      solid black pantsmen track men fall unit botto...
# 4      topwear men tshirt summer puma grey apparel ts...
# ...                                                  ...
# 41686  topwomen topwear print sepia summer top blue a...
# 41687  caddi casual men summer shoemen white shoe gas...
# 41688  flip lotto flopmen track summer men soccer red...
# 41689  topwear stellar men tshirt puma fall graphic b...
# 41690  chronograph watch dial accessori es3050women w...
#
#                                                lemm_noun  \
# 0                            shirtmen men shirts apparel
# 1      peter party men summer jeansmen england appare...
# 2            silver watchwomen accessories watches women
# 3                          pantsmen men manchester pants
# 4         men tshirts summer puma grey apparel tshirtmen
# ...                                                  ...
# 41686                         topwomen summer tops women
# 41687                       men summer shoemen shoes gas
# 41688        flip lotto flopmen summer mens soccer flops
# 41689                 men tshirts fall apparel tshirtmen
# 41690  chronograph watch dial accessories winter foss...
#
#                                                noun_lemm
# 0      shirtmen turtle topwear men fall shirt check b...
# 1      peter party men summer jeansmen blue bottomwea...
# 2      silver watchwomen titan accessory winter watch...
# 3      solid black pantsmen track men fall united bot...
# 4      topwear men tshirts summer puma grey apparel t...
# ...                                                  ...
# 41686  topwomen topwear printed sepia summer top blue...
# 41687  caddy casual men summer shoemen white shoe gas...
# 41688  flip lotto flopmen track summer men soccer red...
# 41689  topwear stellar men tshirts puma fall graphic ...
# 41690  chronograph watch dial accessory es3050women w...
#
# [41691 rows x 19 columns]

# %%
half_size = len(df) // 5
df_copy = df.iloc[:half_size]
df_copy
# Out:
#          id   gender masterCategory  subCategory    articleType  baseColour  \
# 0     15970     men        apparel      topwear         shirts   navy blue
# 1     39386     men        apparel   bottomwear          jeans        blue
# 2     59263   women    accessories      watches        watches      silver
# 3     21379     men        apparel   bottomwear    track pants       black
# 4     53759     men        apparel      topwear        tshirts        grey
# ...     ...      ...            ...          ...            ...         ...
# 8333   4405     men        apparel      topwear        tshirts       black
# 8334  15052     men       footwear        shoes   formal shoes       black
# 8335  52795     men    accessories      wallets        wallets       brown
# 8336  37302   women    accessories      watches        watches       white
# 8337   6352  unisex       footwear       sandal        sandals   navy blue
#
#        season    year    usage  \
# 0       fall   2011.0  casual
# 1     summer   2012.0  casual
# 2     winter   2016.0  casual
# 3       fall   2011.0  casual
# 4     summer   2012.0  casual
# ...       ...     ...      ...
# 8333  summer   2011.0  casual
# 8334  summer   2013.0  formal
# 8335  summer   2012.0  casual
# 8336  winter   2016.0  casual
# 8337  summer   2011.0  casual
#
#                                      productDisplayName      image  \
# 0                     turtle check men navy blue shirt   15970.jpg
# 1                   peter england men party blue jeans   39386.jpg
# 2                             titan women silver watch   59263.jpg
# 3        manchester united men solid black track pants   21379.jpg
# 4                                 puma men grey tshirt   53759.jpg
# ...                                                 ...        ...
# 8333           nirvana mens shoulder fade black tshirt    4405.jpg
# 8334                franco leone men black formal shoe   15052.jpg
# 8335            jag men chocolate brown leather wallet   52795.jpg
# 8336  casio enticer women offwhite multidial watch l...  37302.jpg
# 8337                             crocs kids navy clogs    6352.jpg
#
#                                             allFeatures  \
# 0     shirtmen turtle topwear men fall shirts check ...
# 1     peter party men summer jeansmen blue bottomwea...
# 2     silver watchwomen titan accessories winter wat...
# 3     solid black pantsmen track men fall united bot...
# 4     topwear men tshirts summer puma grey apparel t...
# ...                                                 ...
# 8333  black topwear nirvana tshirts summer fade mens...
# 8334  black franco men summer shoemen leone shoes fo...
# 8335  brown jag leather wallets men accessories summ...
# 8336  watch enticer multidial accessories ltp2083l4a...
# 8337  summer crocs clogsunisex navy blue footwear sa...
#
#                                              lemmatised  \
# 0     shirtmen turtle topwear men fall shirt check b...
# 1     peter party men summer jeansmen blue bottomwea...
# 2     silver watchwomen titan accessory winter watch...
# 3     solid black pantsmen track men fall united bot...
# 4     topwear men tshirts summer puma grey apparel t...
# ...                                                 ...
# 8333  black topwear nirvana tshirts summer fade men ...
# 8334  black franco men summer shoemen leone shoe for...
# 8335  brown jag leather wallet men accessory summer ...
# 8336  watch enticer multidial accessory ltp2083l4avd...
# 8337  summer crocs clogsunisex navy blue footwear sa...
#
#                                            snow_stemmed  \
# 0     shirtmen turtl topwear men fall shirt check bl...
# 1     peter parti men summer jeansmen blue bottomwea...
# 2     silver watchwomen titan accessori winter watch...
# 3     solid black pantsmen track men fall unit botto...
# 4     topwear men tshirt summer puma grey apparel ts...
# ...                                                 ...
# 8333  black topwear nirvana tshirt summer fade men s...
# 8334  black franco men summer shoemen leon shoe form...
# 8335  brown jag leather wallet men accessori summer ...
# 8336  watch entic multidi accessori ltp2083l4avdfa53...
# 8337  summer croc clogsunisex navi blue footwear san...
#
#                                                    noun  \
# 0                           shirtmen men shirts apparel
# 1     peter party men summer jeansmen england appare...
# 2           silver watchwomen accessories watches women
# 3                         pantsmen men manchester pants
# 4        men tshirts summer puma grey apparel tshirtmen
# ...                                                 ...
# 8333  nirvana tshirts summer fade mens apparel tshir...
# 8334     franco men summer shoemen leone shoes footwear
# 8335  jag wallets men accessories summer chocolate w...
# 8336  watch enticer accessories winter offwhite watc...
# 8337       summer crocs clogsunisex sandal sandals kids
#
#                                               stem_lemm  \
# 0     shirtmen turtle topwear men fall shirt check b...
# 1     peter party men summer jeansmen blue bottomwea...
# 2     silver watchwomen titan accessory winter watch...
# 3     solid black pantsmen track men fall united bot...
# 4     topwear men tshirts summer puma grey apparel t...
# ...                                                 ...
# 8333  black topwear nirvana tshirts summer fade men ...
# 8334  black franco men summer shoemen leone shoe for...
# 8335  brown jag leather wallet men accessory summer ...
# 8336  watch enticer multidial accessory ltp2083l4avd...
# 8337  summer crocs clogsunisex navy blue footwear sa...
#
#                                               lemm_stem  \
# 0     shirtmen turtl topwear men fall shirt check bl...
# 1     peter parti men summer jeansmen blue bottomwea...
# 2     silver watchwomen titan accessori winter watch...
# 3     solid black pantsmen track men fall unit botto...
# 4     topwear men tshirt summer puma grey apparel ts...
# ...                                                 ...
# 8333  black topwear nirvana tshirt summer fade men s...
# 8334  black franco men summer shoemen leon shoe form...
# 8335  brown jag leather wallet men accessori summer ...
# 8336  watch entic multidi accessori ltp2083l4avdfa53...
# 8337  summer croc clogsunisex navi blue footwear san...
#
#                                               lemm_noun  \
# 0                           shirtmen men shirts apparel
# 1     peter party men summer jeansmen england appare...
# 2           silver watchwomen accessories watches women
# 3                         pantsmen men manchester pants
# 4        men tshirts summer puma grey apparel tshirtmen
# ...                                                 ...
# 8333  nirvana tshirts summer fade mens apparel tshir...
# 8334     franco men summer shoemen leone shoes footwear
# 8335  jag wallets men accessories summer chocolate w...
# 8336  watch enticer accessories winter offwhite watc...
# 8337       summer crocs clogsunisex sandal sandals kids
#
#                                               noun_lemm
# 0     shirtmen turtle topwear men fall shirt check b...
# 1     peter party men summer jeansmen blue bottomwea...
# 2     silver watchwomen titan accessory winter watch...
# 3     solid black pantsmen track men fall united bot...
# 4     topwear men tshirts summer puma grey apparel t...
# ...                                                 ...
# 8333  black topwear nirvana tshirts summer fade men ...
# 8334  black franco men summer shoemen leone shoe for...
# 8335  brown jag leather wallet men accessory summer ...
# 8336  watch enticer multidial accessory ltp2083l4avd...
# 8337  summer crocs clogsunisex navy blue footwear sa...
#
# [8338 rows x 19 columns]

# %%
def ndcg_at_k_score(y_true, y_pred, k):
    relevance = np.where(y_true == y_pred, 1, 0)
    sorted_relevance = relevance.argsort()[::-1][:k]
    dcg = np.sum(relevance[sorted_relevance] / np.log2(np.arange(2, k+2)))
    idcg = np.sum([1 / np.log2(i+2) for i in range(min(k, len(relevance)))])
    ndcg = dcg / idcg
    return ndcg

# %%
from collections import Counter
def diversity(predicted_labels):
    counts = Counter(predicted_labels)
    num_labels = len(predicted_labels)
    diversity_score = 1 - sum([(count/num_labels)**2 for count in counts.values()])
    return diversity_score

# %%
def novelty(test_labels, predicted_labels):
    unique_test_labels = set(test_labels)
    unique_predicted_labels = set(predicted_labels)
    novel_labels = unique_predicted_labels - unique_test_labels
    novelty_score = len(novel_labels) / len(unique_predicted_labels)
    return novelty_score

# %% [markdown]
# ## allFeatures

# %%
import pandas as pd
from rank_bm25 import BM25Okapi
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix, balanced_accuracy_score
seed = 800

train_data = df_copy.sample(frac=0.8,random_state=seed) #random state is a seed value
test_data  = df_copy.drop(train_data.index)


def bm_25(name):
    train_tokens = [text.split() for text in train_data[name]]
    test_tokens = [text.split() for text in test_data[name]]
    bm25 = BM25Okapi(train_tokens)
    test_scores = [bm25.get_scores(tokens) for tokens in test_tokens]
    predicted_labels = []
    for i in range(len(test_data)):
        bm25_scores = test_scores[i]
        top_match_idx = bm25_scores.argsort()[-1]
        predicted_label = train_data.iloc[top_match_idx]['articleType']
        predicted_labels.append(predicted_label)
    actual_labels = test_data['articleType'].tolist()
    accuracy = accuracy_score(actual_labels, predicted_labels)
    precision = precision_score(actual_labels, predicted_labels, average='weighted')
    recall = recall_score(actual_labels, predicted_labels, average='weighted')
    f1 = f1_score(actual_labels, predicted_labels, average='weighted')
    return predicted_labels, accuracy, precision, recall, f1

start_time_af = time.time()
predicted_labels, accuracy_af, precision_af, recall_af, f1_af = bm_25('allFeatures')
end_time_af = time.time()

print('accuracy_af:', accuracy_af)
print('precision_af:', precision_af)
print('recall_af:', recall_af)
print('f1_af:', f1_af)
time_af = end_time_af - start_time_af
print('Time elapsed:', time_af, 'seconds')


ndcg_af = ndcg_at_k_score(test_data['articleType'], predicted_labels, k=500)
nov_af = novelty(test_data['articleType'], predicted_labels)
div_af = diversity(predicted_labels)
print(ndcg_af, div_af,nov_af)
# Out:
# accuracy_af: 0.9640287769784173
# precision_af: 0.9649385255085673
# recall_af: 0.9640287769784173
# f1_af: 0.9637804148542612
# Time elapsed: 18.90971040725708 seconds
# 1.0 0.9470696823835896 0.0

# %% [markdown]
# ## lemmatised

# %%
start_time_lem = time.time()
accuracy_lem, precision_lem, recall_lem, f1_lem = bm_25('lemmatised')
end_time_lem = time.time()
print('accuracy_lem:', accuracy_lem)
print('precision_lem:', precision_lem)
print('recall_lem:', recall_lem)
print('f1_lem:', f1_lem)
time_lem =  end_time_lem - start_time_lem
print('Time elapsed:', time_lem, 'seconds')
# Out:
# accuracy_lem: 0.9634292565947242
# precision_lem: 0.9661886030233514
# recall_lem: 0.9634292565947242
# f1_lem: 0.9637463586067493
# Time elapsed: 17.539862394332886 seconds

# %% [markdown]
# ## stemmed

# %%
start_time_stem = time.time()
accuracy_stem, precision_stem, recall_stem, f1_stem = bm_25('snow_stemmed')
end_time_stem = time.time()
print('accuracy_stem:', accuracy_stem)
print('precision_stem:', precision_stem)
print('recall_stem:', recall_stem)
print('f1_stem:', f1_stem)
time_stem = end_time_stem - start_time_stem
print('Time elapsed:', time_stem, 'seconds')
# Out:
# accuracy_stem: 0.9616306954436451
# precision_stem: 0.9642673868035742
# recall_stem: 0.9616306954436451
# f1_stem: 0.9618840943660866
# Time elapsed: 17.520114421844482 seconds

# %% [markdown]
# ## noun

# %%
start_time_noun = time.time()
accuracy_noun, precision_noun, recall_noun, f1_noun = bm_25('noun')
end_time_noun = time.time()
print('accuracy_noun:', accuracy_noun)
print('precision_noun:', precision_noun)
print('recall_noun:', recall_noun)
print('f1_noun:', f1_noun)
time_noun = end_time_noun - start_time_noun
print('Time elapsed:', time_noun, 'seconds')
# Out:
# accuracy_noun: 0.9544364508393285
# precision_noun: 0.95736811613686
# recall_noun: 0.9544364508393285
# f1_noun: 0.9550132077177474
# Time elapsed: 10.959463596343994 seconds

# %% [markdown]
# ## stem_lemm

# %%
start_time_stem_lemm = time.time()
accuracy_stem_lemm, precision_stem_lemm, recall_stem_lemm, f1_stem_lemm = bm_25('stem_lemm')
end_time_stem_lemm = time.time()
print('accuracy_stem_lemm:', accuracy_stem_lemm)
print('precision_stem_lemm:', precision_stem_lemm)
print('recall_stem_lemm:', recall_stem_lemm)
print('f1_stem_lemm:', f1_stem_lemm)
time_stem_lemm = end_time_stem_lemm - start_time_stem_lemm
print('Time elapsed:', time_stem_lemm, 'seconds')
# Out:
# accuracy_stem_lemm: 0.9634292565947242
# precision_stem_lemm: 0.9661886030233514
# recall_stem_lemm: 0.9634292565947242
# f1_stem_lemm: 0.9637463586067493
# Time elapsed: 17.698424816131592 seconds

# %% [markdown]
# ## lemm_stem

# %%
start_time_lemm_stem = time.time()
accuracy_lemm_stem, precision_lemm_stem, recall_lemm_stem, f1_lemm_stem = bm_25('lemm_stem')
end_time_lemm_stem = time.time()
print('accuracy_lemm_stem:', accuracy_lemm_stem)
print('precision_lemm_stem:', precision_lemm_stem)
print('recall_lemm_stem:', recall_lemm_stem)
print('f1_lemm_stem:', f1_lemm_stem)
time_lemm_stem = end_time_lemm_stem - start_time_lemm_stem
print('Time elapsed:', time_lemm_stem, 'seconds')
# Out:
# accuracy_lemm_stem: 0.9616306954436451
# precision_lemm_stem: 0.9642673868035742
# recall_lemm_stem: 0.9616306954436451
# f1_lemm_stem: 0.9618840943660866
# Time elapsed: 19.00935959815979 seconds

# %% [markdown]
# ## lemm_noun

# %%
start_time_lemm_noun = time.time()
accuracy_lemm_noun, precision_lemm_noun, recall_lemm_noun, f1_lemm_noun = bm_25('lemm_noun')
end_time_lemm_noun = time.time()
print('accuracy_lemm_noun:', accuracy_lemm_noun)
print('precision_lemm_noun:', precision_lemm_noun)
print('recall_lemm_noun:', recall_lemm_noun)
print('f1_lemm_noun:', f1_lemm_noun)
time_lemm_noun = end_time_lemm_noun - start_time_lemm_noun
print('Time elapsed:', time_lemm_noun, 'seconds')
# Out:
# accuracy_lemm_noun: 0.9544364508393285
# precision_lemm_noun: 0.95736811613686
# recall_lemm_noun: 0.9544364508393285
# f1_lemm_noun: 0.9550132077177474
# Time elapsed: 11.09441065788269 seconds

# %% [markdown]
# ## noun_lemm

# %%
start_time_noun_lemm = time.time()
accuracy_noun_lemm, precision_noun_lemm, recall_noun_lemm, f1_noun_lemm = bm_25('noun_lemm')
end_time_noun_lemm = time.time()
print('accuracy_noun_lemm:', accuracy_noun_lemm)
print('precision_noun_lemm:', precision_noun_lemm)
print('recall_noun_lemm:', recall_noun_lemm)
print('f1_noun_lemm:', f1_noun_lemm)
time_noun_lemm = end_time_noun_lemm - start_time_noun_lemm
print('Time elapsed:', time_noun_lemm, 'seconds')
# Out:
# accuracy_noun_lemm: 0.9634292565947242
# precision_noun_lemm: 0.9661886030233514
# recall_noun_lemm: 0.9634292565947242
# f1_noun_lemm: 0.9637463586067493
# Time elapsed: 17.64653992652893 seconds

# %% [markdown]
# ## Графики

# %% [markdown]
# ### Accurasy

# %%
data = ['allFeatures', 'lemmatised', 'stemmed', 'noun', 'stem_lemm', 'lemm_stem', 'lemm_noun', 'noun_lemm']
accuracy = [accuracy_af, accuracy_lem, accuracy_stem, accuracy_noun, accuracy_stem_lemm, accuracy_lemm_stem, accuracy_lemm_noun, accuracy_noun_lemm]

fig = plt.figure(figsize=(10, 6))

plt.plot(data, accuracy, marker='o', color='blue', label='Accuracy')

plt.xlabel('Data')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison of Different Data for BM-25 algorithm')

plt.show()

# %%
data = ['allFeatures', 'lemmatised', 'stemmed', 'noun', 'stem_lemm', 'lemm_stem', 'lemm_noun', 'noun_lemm']
accuracy = [f1_af, f1_lem, f1_stem, f1_noun, f1_stem_lemm, f1_lemm_stem, f1_lemm_noun, f1_noun_lemm]
print(accuracy)
fig = plt.figure(figsize=(10, 6))
plt.plot(data, accuracy, marker='o', color='blue', label='Accuracy')

plt.xlabel('Data')
plt.ylabel('Accuracy')
plt.title('F1 Comparison of Different Data for BM-25 algorithm')

plt.show()
# Out:
# [0.9637804148542612, 0.9637463586067493, 0.9618840943660866, 0.9550132077177474, 0.9637463586067493, 0.9618840943660866, 0.9550132077177474, 0.9637463586067493]

# %%
data = ['allFeatures', 'lemmatised', 'stemmed', 'noun', 'stem_lemm', 'lemm_stem', 'lemm_noun', 'noun_lemm']
accuracy = [time_af, time_lem, time_stem, time_noun, time_stem_lemm, time_lemm_stem, time_lemm_noun, time_noun_lemm]
print(accuracy)
fig = plt.figure(figsize=(10, 6))
plt.plot(data, accuracy, marker='o', color='blue', label='Accuracy')

plt.xlabel('Data')
plt.ylabel('Accuracy')
plt.title('Time Comparison of Different Data for BM-25 algorithm')

plt.show()
# Out:
# [17.499465465545654, 17.539862394332886, 17.520114421844482, 10.959463596343994, 17.698424816131592, 19.00935959815979, 11.09441065788269, 17.64653992652893]
