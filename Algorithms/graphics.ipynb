# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### bow

# %%
acc_bow = [0.9786030265159765, 0.9792730756975989, 0.9777941486134806, 0.9681540514093487, 0.9792730756975989, 0.9777941486134806, 0.9681540514093487, 0.9792730756975989]
time_bow = [0.8414037227630615, 0.9069242477416992, 0.920842170715332, 0.753192663192749, 0.8985550403594971, 0.9329977035522461, 0.8035078048706055, 0.9456443786621094]

# %% [markdown]
# ### tf-idf

# %%
acc_tf_idf = [0.9588183006516026, 0.9584753371491437, 0.9578801690535934, 0.9550702074451818, 0.9584753371491437, 0.9578801690535934, 0.9550702074451818, 0.9584753371491437]
time_tf_idf = [1.0510447025299072, 1.0141065120697021, 1.0197172164916992, 0.8748667240142822, 1.0131421089172363, 1.0256876945495605, 0.8781743049621582, 1.0145392417907715]

# %% [markdown]
# ### bm-25

# %%
acc_bm25 = [0.9637804148542612, 0.9637463586067493, 0.9618840943660866, 0.9550132077177474, 0.9637463586067493, 0.9618840943660866, 0.9550132077177474, 0.9637463586067493]
time_bm25 = [17.499465465545654, 17.539862394332886, 17.520114421844482, 10.959463596343994, 17.698424816131592, 19.00935959815979, 11.09441065788269, 17.64653992652893]

# %% [markdown]
# ### linear regression

# %%
acc_linear = [0.2917199541916542, 0.2836759792026772, 0.281046546592007, 0.20747407674064902, 0.2836759792026772, 0.281046546592007, 0.20747407674064902, 0.2836759792026772]
time_linear = [0.30507779121398926, 0.4406898021697998, 0.4595351219177246, 0.1796281337738037, 0.5181787014007568, 0.45569276809692383, 0.17380905151367188, 0.4180898666381836]

# %% [markdown]
# ### bayes

# %%
acc_bayes = [0.5095828172870361, 0.09015426597125943, 0.090140940233094, 0.47709494995781987, 0.09015426597125943, 0.090140940233094, 0.47709494995781987, 0.09015426597125943]
time_bayes = [1.8616390228271484, 1.7217650413513184, 1.7393875122070312, 1.133624792098999, 1.7365732192993164, 1.758528470993042, 1.1756203174591064, 1.8968300819396973]

# %% [markdown]
# ### knn

# %%
acc_knn = [0.9733055666539068, 0.9744951432121176, 0.974414194590454, 0.9527534653059287, 0.9744951432121176, 0.974414194590454, 0.9527534653059287, 0.9744951432121176]
time_knn = [0.4853672981262207, 0.5169250965118408, 0.4853024482727051, 0.4543306827545166, 0.4879128932952881, 0.5227558612823486, 0.4123673439025879, 0.5227305889129639]

# %% [markdown]
# ### content filtering

# %%
acc_cont = [0.9835312575053813, 0.9833384435435222, 0.9835474828850908, 0.9720213498790815, 0.9833384435435222, 0.9835474828850908, 0.9720213498790815, 0.9833384435435222]
time_cont = [2.4239413738250732, 2.3167941570281982, 2.3204259872436523, 2.1478898525238037, 2.360605239868164, 2.2666172981262207, 2.1072256565093994, 2.363938093185425]

# %%
data = ['allFeatures', 'lemmatised', 'stemmed', 'noun', 'stem_lemm', 'lemm_stem', 'lemm_noun', 'noun_lemm']


fig = plt.figure(figsize=(10, 6))
#plt.plot(data, acc_bow, marker='o', color='b', label='BOW')
#plt.plot(data, acc_tf_idf, marker='o', color='g', label='TF-IDF')
#plt.plot(data, acc_bm25, marker='o', color='r', label='BM-25')
plt.plot(data, acc_linear, marker='o', color='c', label='Linear Regression')
plt.plot(data, acc_bayes, marker='o', color='y', label='Bayes Classifier')
#plt.plot(data, acc_knn, marker='o', color='m', label='KNN')

plt.legend()
plt.xlabel('Data')
plt.ylabel('Accuracy')
#plt.title('Time Comparison of Different Data for K-nearest Neighbors algorithm')

plt.show()

# %%
data = ['allFeatures', 'lemmatised', 'stemmed', 'noun', 'stem_lemm', 'lemm_stem', 'lemm_noun', 'noun_lemm']


fig = plt.figure(figsize=(10, 6))
plt.plot(data, acc_bow, marker='o', color='b', label='BOW')
plt.plot(data, acc_tf_idf, marker='o', color='g', label='TF-IDF')
plt.plot(data, acc_bm25, marker='o', color='r', label='BM-25')
plt.plot(data, acc_knn, marker='o', color='m', label='KNN')

plt.legend()
plt.xlabel('Data')
plt.ylabel('Accuracy')
#plt.title('Time Comparison of Different Data for K-nearest Neighbors algorithm')

plt.show()

# %%
data = ['allFeatures', 'lemmatised', 'stemmed', 'noun', 'stem_lemm', 'lemm_stem', 'lemm_noun', 'noun_lemm']


fig = plt.figure(figsize=(10, 6))
plt.plot(data, time_bow, marker='o', color='b', label='BOW')
plt.plot(data, time_tf_idf, marker='o', color='g', label='TF-IDF')
#plt.plot(data, time_bm25, marker='o', color='r', label='BM-25')
plt.plot(data, time_linear, marker='o', color='c', label='Linear Regression')
plt.plot(data, time_bayes, marker='o', color='y', label='Bayes Classifier')
plt.plot(data, time_knn, marker='o', color='m', label='KNN')

plt.legend()
plt.xlabel('Data')
plt.ylabel('Accuracy')
#plt.title('Time Comparison of Different Data for K-nearest Neighbors algorithm')

plt.show()

# %%
data = ['allFeatures', 'lemmatised', 'stemmed', 'noun', 'stem_lemm', 'lemm_stem', 'lemm_noun', 'noun_lemm']


fig = plt.figure(figsize=(10, 6))
#plt.plot(data, time_bow, marker='o', color='b', label='BOW')
#plt.plot(data, time_tf_idf, marker='o', color='g', label='TF-IDF')
plt.plot(data, time_bm25, marker='o', color='r', label='BM-25')
#plt.plot(data, time_linear, marker='o', color='c', label='Linear Regression')
#plt.plot(data, time_bayes, marker='o', color='y', label='Bayes Classifier')
#plt.plot(data, time_knn, marker='o', color='m', label='KNN')

plt.legend()
plt.xlabel('Data')
plt.ylabel('Accuracy')
#plt.title('Time Comparison of Different Data for K-nearest Neighbors algorithm')

plt.show()

# %%
data = ['allFeatures', 'lemmatised', 'stemmed', 'noun', 'stem_lemm', 'lemm_stem', 'lemm_noun', 'noun_lemm']


fig = plt.figure(figsize=(10, 6))
plt.plot(data, acc_bow, marker='o', color='b', label='BOW')
plt.plot(data, acc_knn, marker='o', color='r', label='KNN')
plt.plot(data, acc_cont, marker='o', color='m', label='extended_bow_knn')

plt.legend()
plt.xlabel('Data')
plt.ylabel('Accuracy')
#plt.title('Time Comparison of Different Data for K-nearest Neighbors algorithm')

plt.show()

# %%
data = ['allFeatures', 'lemmatised', 'stemmed', 'noun', 'stem_lemm', 'lemm_stem', 'lemm_noun', 'noun_lemm']


fig = plt.figure(figsize=(10, 6))
plt.plot(data, time_bow, marker='o', color='b', label='BOW')
plt.plot(data, time_knn, marker='o', color='r', label='KNN')
plt.plot(data, time_cont, marker='o', color='m', label='extended_bow_knn')

plt.legend()
plt.xlabel('Data')
plt.ylabel('Time')
#plt.title('Time Comparison of Different Data for K-nearest Neighbors algorithm')

plt.show()

# %% [markdown]
# ## diversity

# %%
data = ['BOW', 'KNN', 'extended_bow_knn']
div = [0.9459, 0.9453, 0.9473]

fig = plt.figure(figsize=(5, 3))
plt.plot(data, div, marker='o', color='b', label='Diversity')


plt.legend()
plt.xlabel('Algorithms')
plt.ylabel('Diversity')

plt.show()

# %% [markdown]
# ### novelty

# %%
data = ['BOW', 'KNN', 'extended_bow_knn']
div = [0.01429, 0, 0.1954]

fig = plt.figure(figsize=(5, 3))
plt.plot(data, div, marker='o', color='c', label='Novelty')


plt.legend()
plt.xlabel('Algorithms')
plt.ylabel('Novelty')


plt.show()

# %% [markdown]
# ### ndcg at k

# %%
data = ['BOW', 'KNN', 'extended_bow_knn']
div = [1, 1, 1]

fig = plt.figure(figsize=(5, 3))
plt.plot(data, div, marker='o', color='m', label='NDCG@k')


plt.legend()
plt.xlabel('Algorithms')
plt.ylabel('NDCG@k')
#plt.title('Time Comparison of Different Data for K-nearest Neighbors algorithm')

plt.show()
